# %% [markdown]
# **14/08/2026** -- Supplementary figure S4: Fire PM2.5 proportion of total PM2.5
#
# Note that we are using fire PM2.5 from Hu et al., total PM2.5 from Xu et al. Thus we must restrict the data to 2000-2019 (Xu range).

# %%
Sys.setenv(PROJ_DATA = "/home/users/cho00/miniconda3/envs/ppca/share/proj")

# %%
library(dplyr)
library(readr)
library(sf)
library(ggplot2)
library(cowplot)
# Out:
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
#
# Linking to GEOS 3.13.0, GDAL 3.10.2, PROJ 9.5.1; sf_use_s2() is TRUE

# %%
root <- rprojroot::find_root(rprojroot::has_file(".gitignore"))
source(file.path(root, "src/deprivation_pm_bhm/plotting.R"))    # plot_map() wrapper of ggplot() + geom_sf(), and density_plot()

# %%
# Functions for custom themes of map and density plots
maps_theme <- function() {
    theme(
        legend.position         = "bottom",
        legend.title            = element_text(size = 14, face = "plain"),
        legend.key.height       = NULL,
        legend.key.width        = unit(2, "cm"),
        legend.title.position   = "top",
        axis.text.x             = element_text(color = "black", size = 10)
    )
}

density_theme <- function() {
    theme_minimal() +
    theme(
        axis.title.y    = element_blank(),
        axis.text.y     = element_blank(),
        axis.ticks.y    = element_blank(),
        axis.title.x    = element_blank(),
        panel.grid      = element_blank(),
        axis.line.x     = element_line(color = "black"),
        axis.ticks.x    = element_line(color = "black"),
        axis.text.x     = element_text(color = "black", size = 10),
        panel.background    = element_rect(fill = NA, color = NA),
        plot.background     = element_rect(fill = NA, color = NA)
    )
}

# %%
SCRATCH_DIR <- Sys.getenv("SCRATCH_DIR")
DATA_PATH   <- file.path(SCRATCH_DIR, 
                         "data/spatial/fire_pm_dep_paper_data",
                         "proc_data/df_af_annual_2000_2023.csv")
NAT_BOUNDS_PATH     <- file.path(SCRATCH_DIR, 
                         "data/spatial/nat_boundaries",
                         "WB_countries_Admin0_10m")
western_sahara_path <- file.path(SCRATCH_DIR, 
                         "data/spatial/nat_boundaries",
                         "western_sahara/gadm41_ESH_0.shp")

# %%
df <- read_csv(DATA_PATH)
# Out:
# Rows: 994412 Columns: 74
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (11): geometry, ISO_A3, country, region, continent, INCOME_GRP, ECONOMY,...
# dbl (63): lon, lat, total_PM25, total_O3, fire_PM25, fire_O3, fire_PM25_hu, ...
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.

# %%
nat_bounds <- sf::read_sf(NAT_BOUNDS_PATH) |> 
    filter(CONTINENT == "Africa")

# %%
esh_bounds <- sf::read_sf(western_sahara_path)

# %%
# Get average values over 2000-2019
df_avg <- df |> 
    filter(year <= 2019) |> 
    mutate(fire_frac_hu = 100* fire_PM25_hu / total_PM25) |> 
    group_by(lon, lat) |> 
    summarise(
        geometry    = first(geometry),
        fire_frac   = mean(fire_frac_hu, na.rm = TRUE),
        .groups     = "drop"
    )

# %%
# Convert to sf
sf <- df_avg |> 
    mutate(geometry = sf::st_as_sfc(geometry)) |> 
    sf::st_as_sf(crs = 4326)

# %%
fire_frac_map <- plot_map(
    data = sf, 
    color = "fire_frac",
    fill = "fire_frac", 
    name = "Fire fraction of total PM₂.₅ (%)", 
    palette = "Purples", 
    ticks_color = "black", 
    nat_bounds_sf = nat_bounds, 
    grid_off = FALSE
) +
    geom_sf(data = esh_bounds, color = "black", fill = "gray40") +
    maps_theme()

# %%
dens_fire_frac <- density_plot(sf, 
                               variable = "fire_frac",
                               from = 0,
                               palette = "Purples") + 
    scale_x_continuous(expand = c(0, 0)) +
    scale_y_continuous(expand = expansion(mult = c(0, 0.05))) +
    density_theme()

# %%
options(repr.plot.width = 8, repr.plot.height = 8)

# %%
suppressWarnings({
    fire_frac_with_density <- ggdraw() +
        draw_plot(fire_frac_map, 0, 0, 1, 1) +
        # position the density kernels
        draw_plot(dens_fire_frac, 
                  x = 0.215, 
                  y = 0.23,
                  width = 0.2, 
                  height = 0.28)
})
fire_frac_with_density
# Out:
# plot without title

# %%
ggsave(
    filename = file.path(root, "paper_results/figures/supplementary_fig_S4.png"),
    dpi = 450,
    width = 8,
    height = 8,
    bg = "white"
)
